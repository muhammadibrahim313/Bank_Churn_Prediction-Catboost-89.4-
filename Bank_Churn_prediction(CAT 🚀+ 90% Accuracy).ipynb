# %% [markdown]
# <!-- %%html -->
# <style>
#     div{
#         height: 40px;
#         width: 300px;
#     }
# .custom-heading {
#     background-color:#1a1a1a;/* Blue background color#6b6460 */
#     color:red;   /* Text color */
#     /* font */
#     font-family: Courier;
#     font-size: 15px;
#     padding: 8px 16px;   /* Padding around the text */
#     border-radius: 98px 40px 160px 8px;  /* Rounded corners on the left side */
#     border-left: 8px solid #1eff00;
#     display: flex;
#     align-items:left;
#     justify-content: left;
#     font-weight: bold;
# }
# </style>
#
# <div class="custom-heading">
#     <h2 style="margin: 5;"><a id="1">1. Introduction</a></h2>
# </div>

# %% [markdown]
# <!-- # <span style="color:#FFFFFF; font-size: 0%;">1 | Introduction</span>
# <div style="border-radius: 0px; background-color: #112241; text-align:center;">
#     <h4 style="color: white; padding: 1.5rem; font-size: 19px"><b>1 | INTRODUCTION</b></h4>
# </div>
# <!-- <br> -->
#
# <div style="display: flex; flex-direction: row; align-items: center;">
#     <div style="flex : 0; margin-top: 12px;">
#         <img src="https://i.pinimg.com/736x/54/f3/88/54f38833adcae81ae7cf5a0b0152e62a.jpg" alt="Image" style="max-width: 330px; max-height:300px;" />
#     </div>
#     <div style="flex: 1; margin-left: 30px; margin-top: 6px">
#         <h1><b>Unlocking Bank Churn Secrets: A Data Scientist's Journey</b></h1>
#
# Hello! I'm <h3><b>Muhammad Ibrahim Qasmi</b></h3>  a fervent Data Scientist. This notebook is created for Binary Classification with a Bank Churn Dataset in the **Playground Season-4 Episode-1**.Join me in swiftly decoding the **Bank Churn Dataset** using innovative **ML techniques**, boasting a stellar 90% accuracy. Let's delve into insightful discussions. If you find this nugget of knowledge valuable, an **upvote** would be much appreciated! 🚀❤️
#     </div>
# </div>

# %% [markdown]
# <span style="color:#FFFFFF; font-size: 18px; font-weight: bold;">If anyone wishes to delve deeper into the subject, kindly follow me through the provided links:
# </span> \
# <a href="https://github.com/muhammadibrahim313/muhammadibrahim313">GitHub</a>\
# <a href="https://www.kaggle.com/muhammadibrahimqasmi">Kaggle</a> \
# <a href="https://www.linkedin.com/in/muhammad-ibrahim-9876a1297/">LinkedIn</a> \
# <a href="oppoibrahim23@gmail.com">Gmail</a>

# %% [markdown]
# # Table of Contents:
#
# **1. [Introduction](#1)** <br>
# **2. [MetaData](#2)** <br>
# **3. [Libraries](#3)** <br>
# **4. [LoadData](#4)** <br>
# **5. [Exploratory Data Analysis](#5)** <br>
# **6. [FeatureEngineering](#6)** <br>
# **7. [Modelling](#7)** <br>
# **8. [Submission](#8)** <br>
# **9. [Conclusion](#9)** <br>

# %% [markdown]
# <!-- %%html -->
# <style>
#     div{
#         height: 40px;
#         width: 300px;
#     }
# .custom-heading {
#     background-color:#1a1a1a;/* Blue background color#6b6460 */
#     color:red;   /* Text color */
#     /* font */
#     font-family: Courier;
#     font-size: 15px;
#     padding: 8px 16px;   /* Padding around the text */
#     border-radius: 98px 40px 160px 8px;  /* Rounded corners on the left side */
#     border-left: 8px solid #1eff00;
#     display: flex;
#     align-items:left;
#     justify-content: left;
#     font-weight: bold;
# }
# </style>
#
# <div class="custom-heading">
#     <h2 style="margin: 5;"><a id="2">2. MetaData</a></h2>
# </div>

# %% [markdown]
# # 1. Data Exploration: <a name="data"></a>
# - The dataset for this competition (both train and test) was generated from a deep learning model trained on the [Bank Customer Churn Prediction dataset](https://www.kaggle.com/datasets/shantanudhakadd/bank-customer-churn-prediction). Feature distributions are close to, but not exactly the same, as the original.
#
# ## 1.1 Data Description:
#
# - **Customer ID:** A unique identifier for each customer
# - **Surname:** The customer's surname or last name
# - **Credit Score:** A numerical value representing the customer's credit score
# - **Geography:** The country where the customer resides
# - **Gender:** The customer's gender
# - **Age:** The customer's age.
# - **Tenure:** The number of years the customer has been with the bank
# - **Balance:** The customer's account balance
# - **NumOfProducts:** The number of bank products the customer uses (e.g., savings account, credit card)
# - **HasCrCard:** Whether the customer has a credit card
# - **IsActiveMember:** Whether the customer is an active member
# - **EstimatedSalary:** The estimated salary of the customer
# - **Exited:** Whether the customer has churned (Target Variable)

# %% [markdown]
# <!-- %%html -->
# <style>
#     div{
#         height: 40px;
#         width: 300px;
#     }
# .custom-heading {
#     background-color:#1a1a1a;/* Blue background color#6b6460 */
#     color:red;   /* Text color */
#     /* font */
#     font-family: Courier;
#     font-size: 15px;
#     padding: 8px 16px;   /* Padding around the text */
#     border-radius: 98px 40px 160px 8px;  /* Rounded corners on the left side */
#     border-left: 8px solid #1eff00;
#     display: flex;
#     align-items:left;
#     justify-content: left;
#     font-weight: bold;
# }
# </style>
#
# <div class="custom-heading">
#     <h2 style="margin: 5;"><a id="3">3. Libraries</a></h2>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
from catboost import CatBoostClassifier
from sklearn.inspection import permutation_importance
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <!-- %%html -->
# <style>
#     div{
#         height: 40px;
#         width: 300px;
#     }
# .custom-heading {
#     background-color:#1a1a1a;/* Blue background color#6b6460 */
#     color:red;   /* Text color */
#     /* font */
#     font-family: Courier;
#     font-size: 15px;
#     padding: 8px 16px;   /* Padding around the text */
#     border-radius: 98px 40px 160px 8px;  /* Rounded corners on the left side */
#     border-left: 8px solid #1eff00;
#     display: flex;
#     align-items:left;
#     justify-content: left;
#     font-weight: bold;
# }
# </style>
#
# <div class="custom-heading">
#     <h2 style="margin: 5;"><a id ="4">4. LoadData</a></h2>
# </div>

# %% [markdown]
# ## **Files**
# `train.csv:` The training dataset; Exited is the binary target.\
# `test.csv:`  The test dataset; your objective is to predict the probability of Exited\
# `sample_submission.csv`: A sample submission file in the correct format

# %%
#Loading the data
train= pd.read_csv('data/train.csv')
test= pd.read_csv('data/test.csv')
sample_submission= pd.read_csv('data/sample_submission.csv')

# %% [markdown]
# <!-- %%html -->
# <style>
#     div{
#         height: 40px;
#         width: 260px;
#     }
# .custom-heading {
#     background-color:#1a1a1a;/* Blue background color#6b6460 */
#     color:red;   /* Text color */
#     /* font */
#     font-family: Courier;
#     font-size: 15px;
#     padding: 8px 16px;   /* Padding around the text */
#     border-radius: 98px 40px 160px 8px;  /* Rounded corners on the left side */
#     border-left: 8px solid #1eff00;
#     display: flex;
#     align-items:left;
#     justify-content: left;
#     font-weight: bold;
# }
# </style>
#
# <div class="custom-heading">
#     <h2 style="margin: 5;"><a id="5">5. EDA </a></h2>
# </div>

# %% [markdown]
# # I will begin by reviewing and managing the `Training Data`.

# %%
#Viewing the first 5 rows
train.head()
# Out:
#    id  CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0   0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1   1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2   2    15694510           Hsueh          678    France   Male  40.0      10
# 3   3    15741417             Kao          581    France   Male  34.0       2
# 4   4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        1.0             0.0        181449.97
# 1       0.00              2        1.0             1.0         49503.50
# 2       0.00              2        1.0             0.0        184866.69
# 3  148882.54              1        1.0             1.0         84560.88
# 4       0.00              2        1.0             1.0         15068.83
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# ...

# %%
#Viewing the last 5 rows
train.tail()
# Out:
#             id  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 165029  165029    15667085       Meng          667     Spain  Female  33.0
# 165030  165030    15665521  Okechukwu          792    France    Male  35.0
# 165031  165031    15664752       Hsia          565    France    Male  31.0
# 165032  165032    15689614     Hsiung          554     Spain  Female  30.0
# 165033  165033    15732798    Ulyanov          850    France    Male  31.0
#
#         Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 165029       2       0.0              1        1.0             1.0
# 165030       3       0.0              1        0.0             0.0
# 165031       5       0.0              1        1.0             1.0
# 165032       7  161533.0              1        0.0             1.0
# 165033       1       0.0              1        1.0             0.0
#
#         EstimatedSalary  Exited
# 165029        131834.75       0
# 165030        131834.45       0
# ...

# %% [markdown]
# ## Shape

# %%
#Viewing the shape
train.shape
# Out:
# (165034, 14)

# %% [markdown]
# ## Summary

# %%
#Viewing the summary
train.describe().round(2).style.format(precision=2).background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_93e54_row0_col0, #T_93e54_row0_col2, #T_93e54_row0_col3, #T_93e54_row0_col4, #T_93e54_row0_col6, #T_93e54_row0_col7, #T_93e54_row0_col8, #T_93e54_row0_col10, #T_93e54_row6_col1, #T_93e54_row7_col0, #T_93e54_row7_col1, #T_93e54_row7_col5, #T_93e54_row7_col9 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_93e54_row0_col1, #T_93e54_row7_col2 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_93e54_row0_col5 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_93e54_row0_col9 {
#   background-color: #b31218;
#   color: #f1f1f1;
# }
# #T_93e54_row1_col0, #T_93e54_row5_col0 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_93e54_row1_col1, #T_93e54_row4_col1, #T_93e54_row5_col1 {
#   background-color: #6b010e;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ## Information

# %%
#Viewing the information
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165034 entries, 0 to 165033
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               165034 non-null  int64
#  1   CustomerId       165034 non-null  int64
#  2   Surname          165034 non-null  object
#  3   CreditScore      165034 non-null  int64
#  4   Geography        165034 non-null  object
#  5   Gender           165034 non-null  object
#  6   Age              165034 non-null  float64
#  7   Tenure           165034 non-null  int64
#  8   Balance          165034 non-null  float64
#  9   NumOfProducts    165034 non-null  int64
#  10  HasCrCard        165034 non-null  float64
#  11  IsActiveMember   165034 non-null  float64
#  12  EstimatedSalary  165034 non-null  float64
#  13  Exited           165034 non-null  int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 17.6+ MB

# %% [markdown]
# ## Missing Values

# %%
#missing values
train.isnull().sum()
# Out:
# id                 0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # `As You can see the training data has no null values`

# %% [markdown]
# ## Target Variable Distribution

# %%
#Viewing the target variable
plt.pie(
    train["Exited"].value_counts(),
    labels=train["Exited"].value_counts().index,
    textprops={"fontsize": 14},
    colors=["#ff9999", "#495680", "#de6264"],
    autopct="%.0f%%",
    explode=[0.05, 0.05],
)
plt.title("Target Variable Distribution", fontsize=14)
plt.show()

# %% [markdown]
# ## `As You can see the target variable is imbalanced and 79% is class 0 and 21% is class 1`

# %% [markdown]
# ## pie plot for gender

# %%
plt.figure(figsize=(6, 6))
labels =["Churn: Yes","Churn:No"]
values = [1869,5163]
labels_gender = ["F","M","F","M"]
sizes_gender = [939,930 , 2544,2619]
colors = ['#ff6666', '#66b3ff']
colors_gender = ['#c2c2f0','#ffb3e6', '#c2c2f0','#ffb3e6']
explode = (0.3,0.3)
explode_gender = (0.1,0.1,0.1,0.1)
textprops = {"fontsize":15}
#Plot
plt.pie(values, labels=labels,autopct='%1.1f%%',pctdistance=1.08, labeldistance=0.8,colors=colors, startangle=90,frame=True, explode=explode,radius=10, textprops =textprops, counterclock = True, )
plt.pie(sizes_gender,labels=labels_gender,colors=colors_gender,startangle=90, explode=explode_gender,radius=7, textprops =textprops, counterclock = True, )
#Draw circle
centre_circle = plt.Circle((0,0),5,color='black', fc='white',linewidth=0)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Churn Distribution w.r.t Gender: Male(M), Female(F)', fontsize=15, y=1.1)

# show plot

plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Create Categorical vars, Numerical vars

# %%
#Viewing the attributes
train.attrs["name"] = "train"
test.attrs["name"] = "test"
#DATA PREPARATION

def prep(df):
    df.columns = df.columns.str.lower()
    df["zero_bal_flag"] = np.where(df["balance"] == 0, "z", "nz")
    df["zero_bal_flag"] = df["zero_bal_flag"].astype("category")
    df["gender_by_geo"] = df["gender"] + "_" + df["geography"]
    df["gender_by_geo"] = df["gender_by_geo"].astype("category")
    df["is_senior"] = np.where(df["age"] > 63, 1, 0)
    df["is_senior"] = df["is_senior"].astype("int32").astype("category")
    df["isactive_by_creditcard"] = np.multiply(df["hascrcard"], df["isactivemember"]).astype("int32").astype("category")
    df["hascrcard"] = df["hascrcard"].astype("int32").astype("category")
    df["products_by_tenure"] = np.divide(df["tenure"], df["numofproducts"])
    df["balance_and_salary_ratio"] =  np.divide(df["balance"], df["estimatedsalary"])
    df["age_cat"] = np.round(np.divide(df["age"], 20)).astype("int").astype("category")
    df["credit_score_cat"] = pd.cut(
        df["creditscore"],
        bins=[0, 450, 650, 750, 850],
        labels=["very_low", "low", "medium", "high"],
    )
    df["credit_score_cat"] = df["credit_score_cat"].astype("category")
    df["isactivemember"] = df["isactivemember"].astype("int32").astype("category")
    df["customer_relationships"] = np.where(df["tenure"] > 1, "new_customer", "long-lasting")
    df["customer_relationships"] = df["customer_relationships"].astype("category")
    df = df.drop("id", axis=1)
    categorical_vars = df.loc[:, df.nunique() <= 4].columns[0:5]
    numerical_vars = df[
        ["customerid", "creditscore", "age", "tenure", "balance", "estimatedsalary"]
    ].columns
    df[categorical_vars] = df[categorical_vars].astype("category")

    return df, categorical_vars, numerical_vars

# %%
#DATA PREPARATION
train, categorical_vars, numerical_vars = prep(train)
test = prep(test)
test = test[0]

# %%
#making  zeero balance flag w.r.t. gender, geography, credit score and products by tenure and active member.
for i in categorical_vars:
    g = sns.FacetGrid(data=train, col=i, height=2.5, aspect=1.5, margin_titles=True)
    g.map_dataframe(
        sns.countplot,
        x="zero_bal_flag",
        hue="gender_by_geo",
        width=0.4,
        palette="Set2",
    )
    g.set_titles(
        col_template="\n---------------------\n{col_var} = {col_name}\n---------------------\n",
        size=8,
    )
    g.add_legend(fontsize=8)
    g.tick_params(labelsize=8)
    g.set_axis_labels(x_var="zero balance Flag", y_var="Counts", fontsize=10)

plt.show()

# %%
# distribution of exited w.r.t. customer_relationships.
for i in categorical_vars:
    g = sns.FacetGrid(data=train, col=i, height=2.5, aspect=1.5, margin_titles=True)
    g.map_dataframe(
        sns.countplot,
        x="exited",
        hue="customer_relationships",
        width=0.4,
        palette="Set2",
    )
    g.set_titles(
        col_template="\n---------------------\n{col_var} = {col_name}\n---------------------\n",
        size=8,
    )
    g.add_legend(fontsize=8)
    g.tick_params(labelsize=8)
    g.set_axis_labels(x_var="Exited", y_var="Counts", fontsize=10)

plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
plt.style.use("default")
corr_mat = train[numerical_vars].corr()
mask = np.triu(np.ones_like(corr_mat, dtype=bool))
cmap = sns.diverging_palette(230, 30, as_cmap=True)
f, ax = plt.subplots(figsize=(9, 7))
sns.heatmap(
    corr_mat,
    mask=mask,
    cbar=False,
    cmap=cmap,
    fmt="0.2f",
    center=0,
    square=False,
    annot=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.8},
)
plt.title("Correlation Matrix (Train Datase)\n")
plt.xticks(fontsize=9)
plt.yticks(fontsize=9)
plt.show()

# %% [markdown]
# # Test Data

# %% [markdown]
# ## Now we will look at the test data

# %%
#Viewing the first 5 rows
test.head()
# Out:
#    customerid    surname  creditscore geography  gender   age  tenure  \
# 0    15773898   Lucchese          586    France  Female  23.0       2
# 1    15782418       Nott          683    France  Female  46.0       2
# 2    15807120         K?          656    France  Female  34.0       7
# 3    15808905  O'Donnell          681    France    Male  36.0       8
# 4    15607314    Higgins          752   Germany    Male  38.0      10
#
#      balance numofproducts hascrcard  ... estimatedsalary  zero_bal_flag  \
# 0       0.00             2         0  ...       160976.75              z
# 1       0.00             1         1  ...        72549.27              z
# 2       0.00             2         1  ...       138882.09              z
# 3       0.00             1         1  ...       113931.57              z
# 4  121263.62             1         1  ...       139431.00             nz
#
#    gender_by_geo is_senior isactive_by_creditcard products_by_tenure  \
# ...

# %%
# tail
test.tail()
# Out:
#         customerid   surname  creditscore geography  gender   age  tenure  \
# 110018    15662091     P'eng          570     Spain    Male  29.0       7
# 110019    15774133       Cox          575    France  Female  36.0       4
# 110020    15728456     Ch'iu          712    France    Male  31.0       2
# 110021    15687541  Yegorova          709    France  Female  32.0       3
# 110022    15663942      Tuan          621    France  Female  37.0       7
#
#           balance numofproducts hascrcard  ... estimatedsalary  zero_bal_flag  \
# 110018  116099.82             1         1  ...       148087.62             nz
# 110019  178032.53             1         1  ...        42181.68             nz
# 110020       0.00             2         1  ...        16287.38              z
# 110021       0.00             1         1  ...       158816.58              z
# 110022   87848.39             1         1  ...        24210.56             nz
#
# ...

# %% [markdown]
# ## Shape

# %%
#Viewing the shape
test.shape
# Out:
# (110023, 21)

# %% [markdown]
# ## Summary

# %%
# summary
test.describe().round(2).style.format(precision=2).background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_233ea_row0_col0, #T_233ea_row1_col2, #T_233ea_row1_col3, #T_233ea_row1_col6, #T_233ea_row1_col7, #T_233ea_row2_col0, #T_233ea_row2_col1, #T_233ea_row2_col2, #T_233ea_row2_col3, #T_233ea_row2_col6, #T_233ea_row2_col7, #T_233ea_row3_col1, #T_233ea_row3_col2, #T_233ea_row3_col3, #T_233ea_row3_col4, #T_233ea_row3_col5, #T_233ea_row3_col6, #T_233ea_row3_col7, #T_233ea_row4_col2, #T_233ea_row4_col3, #T_233ea_row4_col4, #T_233ea_row4_col6, #T_233ea_row4_col7, #T_233ea_row5_col2, #T_233ea_row5_col3, #T_233ea_row5_col4, #T_233ea_row5_col6, #T_233ea_row5_col7, #T_233ea_row6_col2, #T_233ea_row6_col3, #T_233ea_row6_col6, #T_233ea_row6_col7, #T_233ea_row7_col2, #T_233ea_row7_col3, #T_233ea_row7_col6 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_233ea_row0_col1, #T_233ea_row0_col2, #T_233ea_row0_col3, #T_233ea_row0_col6, #T_233ea_row0_col7, #T_233ea_row6_col0, #T_233ea_row7_col0, #T_233ea_row7_col4, #T_233ea_row7_col5 {
#   background-color: #67000d;
# ...

# %% [markdown]
# ## Information

# %%
#Viewing the information
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110023 entries, 0 to 110022
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   customerid                110023 non-null  int64
#  1   surname                   110023 non-null  object
#  2   creditscore               110023 non-null  int64
#  3   geography                 110023 non-null  category
#  4   gender                    110023 non-null  category
#  5   age                       110023 non-null  float64
#  6   tenure                    110023 non-null  int64
#  7   balance                   110023 non-null  float64
#  8   numofproducts             110023 non-null  category
#  9   hascrcard                 110023 non-null  category
#  10  isactivemember            110023 non-null  category
#  11  estimatedsalary           110023 non-null  float64
#  12  zero_bal_flag             110023 non-null  category
# ...

# %% [markdown]
# ## Correlation Matrix

# %%
plt.style.use("default")
corr_mat = test[numerical_vars].corr()
mask = np.triu(np.ones_like(corr_mat, dtype=bool))
cmap = sns.diverging_palette(200, 60, as_cmap=True)
f, ax = plt.subplots(figsize=(9, 7))
sns.heatmap(
    corr_mat,
    mask=mask,
    cbar=False,
    cmap=cmap,
    fmt="0.2f",
    center=0,
    square=False,
    annot=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.8},
)
plt.title("Correlation Matrix (Test Dataset)\n")
plt.xticks(fontsize=9)
plt.yticks(fontsize=9)
plt.show()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165034 entries, 0 to 165033
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   customerid                165034 non-null  int64
#  1   surname                   165034 non-null  object
#  2   creditscore               165034 non-null  int64
#  3   geography                 165034 non-null  category
#  4   gender                    165034 non-null  category
#  5   age                       165034 non-null  float64
#  6   tenure                    165034 non-null  int64
#  7   balance                   165034 non-null  float64
#  8   numofproducts             165034 non-null  category
#  9   hascrcard                 165034 non-null  category
#  10  isactivemember            165034 non-null  category
#  11  estimatedsalary           165034 non-null  float64
#  12  exited                    165034 non-null  int64
# ...

# %%
train.head().T
# Out:
#                                        0              1             2  \
# customerid                      15674932       15749177      15694510
# surname                   Okwudilichukwu  Okwudiliolisa         Hsueh
# creditscore                          668            627           678
# geography                         France         France        France
# gender                              Male           Male          Male
# age                                 33.0           33.0          40.0
# tenure                                 3              1            10
# balance                              0.0            0.0           0.0
# numofproducts                          2              2             2
# hascrcard                              1              1             1
# isactivemember                         0              1             0
# estimatedsalary                181449.97        49503.5     184866.69
# ...

# %% [markdown]
# <!-- %%html -->
# <style>
#     div{
#         height: 40px;
#         width: 400px;
#     }
# .custom-heading {
#     background-color:#1a1a1a;/* Blue background color#6b6460 */
#     color:red;   /* Text color */
#     /* font */
#     font-family: Courier;
#     font-size: 15px;
#     padding: 8px 16px;   /* Padding around the text */
#     border-radius: 98px 40px 160px 8px;  /* Rounded corners on the left side */
#     border-left: 8px solid #1eff00;
#     display: flex;
#     align-items:left;
#     justify-content: left;
#     font-weight: bold;
# }
# </style>
#
# <div class="custom-heading">
#     <h2 style="margin: 5;"><a id="6">6. FeatureEngineering</a></h2>
# </div>

# %%
categorical_features = train.select_dtypes(
    include=["object", "category"]
).columns.to_list()
train[categorical_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165034 entries, 0 to 165033
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   surname                 165034 non-null  object
#  1   geography               165034 non-null  category
#  2   gender                  165034 non-null  category
#  3   numofproducts           165034 non-null  category
#  4   hascrcard               165034 non-null  category
#  5   isactivemember          165034 non-null  category
#  6   zero_bal_flag           165034 non-null  category
#  7   gender_by_geo           165034 non-null  category
#  8   is_senior               165034 non-null  category
#  9   isactive_by_creditcard  165034 non-null  category
#  10  age_cat                 165034 non-null  category
#  11  credit_score_cat        165034 non-null  category
#  12  customer_relationships  165034 non-null  category
# dtypes: category(12), object(1)
# ...

# %% [markdown]
# <!-- %%html -->
# <style>
#     div{
#         height: 40px;
#         width: 300px;
#     }
# .custom-heading {
#     background-color:#1a1a1a;/* Blue background color#6b6460 */
#     color:red;   /* Text color */
#     /* font */
#     font-family: Courier;
#     font-size: 15px;
#     padding: 8px 16px;   /* Padding around the text */
#     border-radius: 98px 40px 160px 8px;  /* Rounded corners on the left side */
#     border-left: 8px solid #1eff00;
#     display: flex;
#     align-items:left;
#     justify-content: left;
#     font-weight: bold;
# }
# </style>
#
# <div class="custom-heading">
#     <h2 style="margin: 5;"><a id="7">7. Modelling</a></h2>
# </div>

# %%
rand_state = 1
# making X and Y
test_df = test.drop(columns=["customerid"], axis=1)
X = train.drop(columns=["customerid", "exited"])
y = train["exited"]
# splitting
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=rand_state, 
                                                    stratify=y)

# %% [markdown]
# # Catboost Classifier

# %% [markdown]
# ##  Define model

# %%
# define model
catboost_model = CatBoostClassifier(
    random_seed=rand_state, cat_features=categorical_features, verbose=100, n_estimators=2000
)

# %% [markdown]
# ## Fit model

# %%
# fit the model
catboost_model.fit(X_train, y_train)
y_pred_prob = catboost_model.predict_proba(X_test)[:, 1]
# Out:
# Learning rate set to 0.042702
# 0:	learn: 0.6516588	total: 531ms	remaining: 17m 41s
# 100:	learn: 0.3152819	total: 27.5s	remaining: 8m 37s
# 200:	learn: 0.3107733	total: 56.3s	remaining: 8m 23s
# 300:	learn: 0.3083283	total: 1m 22s	remaining: 7m 47s
# 400:	learn: 0.3062133	total: 1m 46s	remaining: 7m 6s
# 500:	learn: 0.3044769	total: 2m 10s	remaining: 6m 30s
# 600:	learn: 0.3029431	total: 2m 34s	remaining: 5m 59s
# 700:	learn: 0.3015721	total: 2m 58s	remaining: 5m 30s
# 800:	learn: 0.3002183	total: 3m 23s	remaining: 5m 3s
# 900:	learn: 0.2990493	total: 3m 47s	remaining: 4m 37s
# 1000:	learn: 0.2978321	total: 4m 11s	remaining: 4m 11s
# 1100:	learn: 0.2966041	total: 4m 35s	remaining: 3m 45s
# 1200:	learn: 0.2953526	total: 4m 59s	remaining: 3m 19s
# 1300:	learn: 0.2942045	total: 5m 23s	remaining: 2m 53s
# 1400:	learn: 0.2931846	total: 5m 47s	remaining: 2m 28s
# 1500:	learn: 0.2920783	total: 6m 11s	remaining: 2m 3s
# 1600:	learn: 0.2909926	total: 6m 35s	remaining: 1m 38s
# ...

# %% [markdown]
# ## AUC Score

# %%
# roc curve and auc
roc_auc = roc_auc_score(y_test, y_pred_prob)
print(f"roc auc score: {roc_auc:.6f}")
# Out:
# roc auc score: 0.891368

# %% [markdown]
# # Feature Importance

# %%
# feature importance of the model
catboost_model.get_feature_importance(prettified=True).round(2).style.format(
    precision=2
).background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_21f65_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_21f65_row1_col1 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_21f65_row2_col1 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# #T_21f65_row3_col1 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_21f65_row4_col1 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_21f65_row5_col1 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_21f65_row6_col1 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_21f65_row7_col1 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_21f65_row8_col1 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_21f65_row9_col1 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_21f65_row10_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_21f65_row11_col1 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_21f65_row12_col1 {
# ...

# %% [markdown]
# ## Plot Feature Importance

# %%
feature_importance = catboost_model.get_feature_importance(prettified=True)

plt.figure(figsize=(10, 8))
sns.barplot(x="Importances", y="Feature Id", data=feature_importance, palette="Dark2")
plt.title("Feature Importance")
plt.show()

# %% [markdown]
# ## Plot ROC

# %%
plt.style.use("default")
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)


plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkgreen', label='ROC')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %% [markdown]
# ## Predict on test data

# %%
y_pred_test = catboost_model.predict_proba(test_df)[:, 1]
y_pred_test
# Out:
# array([0.01955001, 0.74932723, 0.01436093, ..., 0.00970649, 0.17728501,
#        0.18245655])

# %% [markdown]
# <!-- %%html -->
# <style>
#     div{
#         height: 40px;
#         width: 300px;
#     }
# .custom-heading {
#     background-color:#1a1a1a;/* Blue background color#6b6460 */
#     color:red;   /* Text color */
#     /* font */
#     font-family: Courier;
#     font-size: 15px;
#     padding: 8px 16px;   /* Padding around the text */
#     border-radius: 98px 40px 160px 8px;  /* Rounded corners on the left side */
#     border-left: 8px solid #1eff00;
#     display: flex;
#     align-items:left;
#     justify-content: left;
#     font-weight: bold;
# }
# </style>
#
# <div class="custom-heading">
#     <h2 style="margin: 5;"><a id="8">8. Submission</a></h2>
# </div>

# %%
sample_submission["Exited"] = y_pred_test
sample_submission.to_csv("submission(cat).csv", index=False)
sample_submission.head()
# Out:
#        id    Exited
# 0  165034  0.019550
# 1  165035  0.749327
# 2  165036  0.014361
# 3  165037  0.199014
# 4  165038  0.305977

# %% [markdown]
# <!-- %%html -->
# <style>
#     div{
#         height: 40px;
#         width: 300px;
#     }
# .custom-heading {
#     background-color:#1a1a1a;/* Blue background color#6b6460 */
#     color:red;   /* Text color */
#     /* font */
#     font-family: Courier;
#     font-size: 15px;
#     padding: 8px 16px;   /* Padding around the text */
#     border-radius: 98px 40px 160px 8px;  /* Rounded corners on the left side */
#     border-left: 8px solid #1eff00;
#     display: flex;
#     align-items:left;
#     justify-content: left;
#     font-weight: bold;
# }
# </style>
#
# <div class="custom-heading">
#     <h2 style="margin: 5;"><a id="9">9. Conclusion</a></h2>
# </div>

# %% [markdown]
# <span style="color:#FFFFFF; font-size: 18px; font-weight: bold;">        In brief, our bank churn analysis harnessed the potency of an Advanced Machine Learning (AML) modelCatBoost 🚀 This ensemble, coupled with meticulous feature engineering, delivered a highly accurate predictor.The model not only identifies potential churn scenarios but also offers actionable insights for proactive retention.<br> 📈 This fusion of innovation and advanced algorithms exemplifies the transformative impact of data science on elevating customer relationship management in the banking sector. 💼✨</span>
# </span>

# %% [markdown]
# <span style="color:#KKKK; font-size: 240%; font-weight: bold;">Here's to your success!❤️
# </span>

# %% [markdown]
# ---
